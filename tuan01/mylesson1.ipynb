# %% [markdown]
# # “Thuc hanh tri tue nhan tao Buoi 1”
# ## “Noi dung thuc hanh”

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %%
print("Calculator Basic")
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))
c = a + b
print("c = %d + %d = %d" % (a, b, c))
# Out:
# Calculator Basic
# c = 2 + 3 = 5

# %% [markdown]
# # Ket Thuc

# %%
import math
print("Calculator Basic")
r = float(input("Moi ban nhap ban kinh : "))
chu_vi = 2 * math.pi * r
dien_tich = math.pi * r * r

print(" Chu vi hinh tron la : ", chu_vi)
print("dien tich hinh tron la : ",dien_tich)
# Out:
# Calculator Basic
#  Chu vi hinh tron la :  12.566370614359172
# dien tich hinh tron la :  12.566370614359172
