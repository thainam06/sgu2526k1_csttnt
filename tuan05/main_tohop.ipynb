# %% [markdown]
# BÀI TOÁN TỔ HỢP

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%writefile tophop.txt
# 5 3
# A
# B
# C
# D
# E
# Out:
# Overwriting tophop.txt

# %%
# %run tohop.py --action test1
# Out:
# ----- DOC FILE -----
# n = 5, k = 3, th = ['A', 'B', 'C', 'D', 'E']
# Kết quả:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %run tohop.py --action main --file tophop.txt
# Out:
# ----- DOC FILE -----
# n = 5, k = 3, th = ['A', 'B', 'C', 'D', 'E']
# Kết quả:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %%
# %%writefile tophop_py.txt
# 3 2
# F
# B
# A
# Out:
# Overwriting tophop_py.txt

# %%
# %run tohop.py --action main --file tophop_py.txt
# Out:
# ----- DOC FILE -----
# n = 3, k = 2, th = ['F', 'B', 'A']
# Kết quả:
# 3
# F B
# F A
# B A
